# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('MagicBricks.csv')

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0       800.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 0                                      Rohini Sector 25      1.0   6500000
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# ...

# %%
data.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 286

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1257 non-null   float64
#  3   Furnishing   1254 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1226 non-null   float64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1254 non-null   object
#  10  Per_Sqft     1018 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 108.3+ KB

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# 900.0      67
# 1500.0     50
# 1800.0     48
# 1000.0     42
# 1600.0     38
#            ..
# 150.0       1
# 3250.0      1
# 4000.0      1
# 5500.0      1
# 11050.0     1
# Name: Area, Length: 315, dtype: int64
# ********************
# 3     541
# 2     367
# 4     220
# 1      96
# 5      27
# 6       6
# 7       1
# 10      1
# Name: BHK, dtype: int64
# ********************
# 2.0    551
# 3.0    355
# 1.0    146
# 4.0    138
# 5.0     57
# 6.0      7
# 7.0      3
# Name: Bathroom, dtype: int64
# ********************
# Semi-Furnished    708
# Unfurnished       363
# Furnished         183
# Name: Furnishing, dtype: int64
# ********************
# ...

# %%
data.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1259.000000  1259.000000  1257.000000  1226.000000  1.259000e+03
# mean    1466.452724     2.796664     2.556086     1.935563  2.130670e+07
# std     1568.055040     0.954425     1.042220     6.279212  2.560115e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.700000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.550000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1018.000000
# mean    15690.136542
# std     21134.738568
# min      1259.000000
# 25%      6364.000000
# 50%     11291.500000
# 75%     18000.000000
# max    183333.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1257 non-null   float64
#  3   Furnishing   1254 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1226 non-null   float64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1254 non-null   object
#  10  Per_Sqft     1018 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 108.3+ KB

# %%
data.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
data['Bathroom'].value_counts()
# Out:
# 2.0    551
# 3.0    355
# 1.0    146
# 4.0    138
# 5.0     57
# 6.0      7
# 7.0      3
# Name: Bathroom, dtype: int64

# %%
data['Bathroom'].fillna(2,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1259 non-null   float64
#  3   Furnishing   1254 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1226 non-null   float64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1254 non-null   object
#  10  Per_Sqft     1018 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 108.3+ KB

# %%
data['Furnishing'].value_counts()
# Out:
# Semi-Furnished    708
# Unfurnished       363
# Furnished         183
# Name: Furnishing, dtype: int64

# %%
data['Furnishing'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1254    False
# 1255    False
# 1256    False
# 1257    False
# 1258    False
# Name: Furnishing, Length: 1259, dtype: bool

# %%
mask = False
for col in data['Furnishing']: 
    mask = mask | data['Furnishing'].isnull()
dfnulls = data[mask]

# %%
dfnulls
# Out:
#        Area  BHK  Bathroom Furnishing  \
# 509   450.0    2       2.0        NaN
# 510   540.0    5       2.0        NaN
# 511  1350.0    3       3.0        NaN
# 512  2250.0    3       2.0        NaN
# 719  1500.0    3       2.0        NaN
#
#                                               Locality  Parking     Price  \
# 509                             Gandhi Nagar, Shahdara      NaN   2900000
# 510                             Gandhi Nagar, Shahdara      NaN  17000000
# 511                             Gandhi Nagar, Shahdara      NaN  25000000
# 512                             Gandhi Nagar, Shahdara      NaN  10000000
# 719  Sarita Vihar, Mathura Road carpet area 1500 sq...      1.0  13500000
#
#             Status Transaction Type  Per_Sqft
# 509  Ready_to_move      Resale  NaN   58000.0
# 510  Ready_to_move      Resale  NaN   58000.0
# 511  Ready_to_move      Resale  NaN   18519.0
# 512  Ready_to_move      Resale  NaN    4444.0
# 719  Ready_to_move      Resale  NaN       NaN

# %%
mask = False
for col in data['Furnishing']: 
    mask = mask | data['Furnishing'].isnull()
dfnulls = data[mask]
dfnulls
# Out:
#        Area  BHK  Bathroom Furnishing  \
# 509   450.0    2       2.0        NaN
# 510   540.0    5       2.0        NaN
# 511  1350.0    3       3.0        NaN
# 512  2250.0    3       2.0        NaN
# 719  1500.0    3       2.0        NaN
#
#                                               Locality  Parking     Price  \
# 509                             Gandhi Nagar, Shahdara      NaN   2900000
# 510                             Gandhi Nagar, Shahdara      NaN  17000000
# 511                             Gandhi Nagar, Shahdara      NaN  25000000
# 512                             Gandhi Nagar, Shahdara      NaN  10000000
# 719  Sarita Vihar, Mathura Road carpet area 1500 sq...      1.0  13500000
#
#             Status Transaction Type  Per_Sqft
# 509  Ready_to_move      Resale  NaN   58000.0
# 510  Ready_to_move      Resale  NaN   58000.0
# 511  Ready_to_move      Resale  NaN   18519.0
# 512  Ready_to_move      Resale  NaN    4444.0
# 719  Ready_to_move      Resale  NaN       NaN

# %%
data['Furnishing'].fillna("Semi-Furnished",inplace=True)

# %%
data.sort_values(by=['Furnishing'], na_position="first")
# Out:
#          Area  BHK  Bathroom   Furnishing  \
# 1046   1135.0    3       3.0    Furnished
# 421      70.0    2       3.0    Furnished
# 724     950.0    2       2.0    Furnished
# 725    1200.0    3       3.0    Furnished
# 726    1400.0    4       2.0    Furnished
# ...       ...  ...       ...          ...
# 243    4300.0    4       4.0  Unfurnished
# 420    3901.0    4       4.0  Unfurnished
# 419    4688.0    5       4.0  Unfurnished
# 715    1200.0    2       2.0  Unfurnished
# 1258  11050.0    3       3.0  Unfurnished
#
#                                                Locality  Parking      Price  \
# 1046                          The Amaryllis, Karol Bagh      2.0   24500000
# 421                      Patel Nagar South, Patel Nagar      1.0    8200000
# 724   DDA Flats Sarita Vihar, Sarita Vihar, Mathura ...      2.0   12900000
# 725   DDA Flats Sarita Vihar, Sarita Vihar, Mathura ...      2.0   13500000
# ...

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0       800.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 0                                      Rohini Sector 25      1.0   6500000
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# ...

# %%
data.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         0
# Furnishing       0
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
data[data.BHK >5]
# Out:
#        Area  BHK  Bathroom      Furnishing  \
# 163  4050.0    6       3.0       Furnished
# 164  2400.0    6       4.0       Furnished
# 261  2800.0    6       4.0  Semi-Furnished
# 345  2970.0    7       4.0       Furnished
# 352   324.0    6       3.0       Furnished
# 353   720.0    6       5.0       Furnished
# 585  5500.0    6       7.0       Furnished
# 721  1200.0   10       4.0  Semi-Furnished
#
#                                               Locality  Parking      Price  \
# 163                                 Budh Vihar Phase 1      1.0    5100000
# 164                                 Budh Vihar Phase 2      1.0    6000000
# 261  Taimoor Enclave, New Friends Colony carpet are...      2.0   29500000
# 345                             Yamuna Vihar, Shahdara      1.0   26500000
# 352                             Yamuna Vihar, Shahdara      1.0    8700000
# 353                             Yamuna Vihar, Shahdara      1.0   22000000
# ...

# %%
data['Per_Sqft'].unique()
# Out:
# array([    nan,   6667.,   6154.,   6364.,   8750.,   9722.,  14444.,
#         22000.,   2235.,   3800.,   4247.,   3524.,  26666.,  15972.,
#        183333.,  20000.,  15556.,  16176.,   9259.,  18507.,   7000.,
#         72000.,  43000.,   4444.,   3300.,  40000.,   5185.,   4000.,
#          3567.,   1259.,   2500.,   5255.,   6528.,   6875.,   5714.,
#          7449.,   8125.,   7931.,   5789.,   6471.,   8438.,   6508.,
#          8000.,   6000.,   6250.,   6333.,   6714.,  28797.,  23840.,
#          4600.,   4620.,   5000.,   6111.,  25512.,  22222.,  24718.,
#         30556.,  18750., 120000.,  15459.,  23529.,  16667.,  11111.,
#         21409.,  95000.,  15363.,  19259.,  20833.,  20930.,   6526.,
#          3901.,   6347.,  41304.,   8701.,   5556.,  85715.,   6944.,
#          7222.,  11220.,   5357.,   6706.,  10288.,  28283.,   8923.,
#          8222.,  14550.,  30093.,  35714.,  22857.,  12500.,   4040.,
# ...

# %%
data.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
data['Per_Sqft'] = round(data['Price'] / data['Area'])

# %%
data.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor    8125.0
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment   16316.0
# 3  Ready_to_move        Resale  Builder_Floor    7000.0
# ...

# %%
data['Locality'].value_counts()
# Out:
# Lajpat Nagar 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  34
# ...

# %%
data['Locality'] = data['Locality'].apply(lambda x:x.strip())

# %%
data['Locality'].value_counts()
# Out:
# Lajpat Nagar 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  34
# ...

# %%
location_count = data['Locality'].value_counts()

# %%
location_less_than_10 = location_count[location_count <=5]

# %%
location_less_than_10
# Out:
# Panchsheel Vihar, Sheikh Sarai                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  5
# ...

# %%
data['Locality'] = data['Locality'].apply(lambda x: 'other' if x in location_less_than_10 else x)

# %%
data['Locality'].value_counts()
# Out:
# other                                                                       510
# Lajpat Nagar 3                                                               34
# Lajpat Nagar 2                                                               33
# J R Designers Floors, Rohini Sector 24                                       31
# Kailash Colony, Greater Kailash                                              30
# Yamuna Vihar, Shahdara                                                       29
# Laxmi Nagar                                                                  25
# Mehrauli                                                                     24
# Chittaranjan Park                                                            24
# Saket                                                                        21
# Alaknanda                                                                    20
# DDA Flats Sarita Vihar, Sarita Vihar, Mathura Road                           19
# ...

# %%
data.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1259.000000  1259.000000  1259.000000  1226.000000  1.259000e+03
# mean    1466.452724     2.796664     2.555203     1.935563  2.130670e+07
# std     1568.055040     0.954425     1.041627     6.279212  2.560115e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.700000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.550000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1259.000000
# mean    14582.158062
# std     20420.178997
# min       204.000000
# 25%      6757.500000
# 50%     11667.000000
# 75%     17550.000000
# max    538462.000000

# %%
(data['Area']/data['BHK']).describe()
# Out:
# count    1259.000000
# mean      501.167417
# std       416.755438
# min        11.250000
# 25%       350.000000
# 50%       450.000000
# 75%       551.250000
# max      6075.000000
# dtype: float64

# %%
data = data[((data['Area']/data['BHK']) >= 300)]

# %%
data.shape
# Out:
# (1083, 11)

# %%
data.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1083.000000  1083.000000  1083.000000  1055.000000  1.083000e+03
# mean    1617.612117     2.833795     2.665743     1.988626  2.379839e+07
# std     1638.593474     0.940996     1.040314     6.564514  2.669037e+07
# min      300.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      945.000000     2.000000     2.000000     1.000000  7.200000e+06
# 50%     1350.000000     3.000000     2.000000     1.000000  1.580000e+07
# 75%     1800.000000     3.000000     3.000000     2.000000  2.850000e+07
# max    24300.000000     7.000000     7.000000   114.000000  2.400000e+08
#
#            Per_Sqft
# count   1083.000000
# mean   13332.455217
# std     7464.567486
# min      204.000000
# 25%     7456.000000
# 50%    12222.000000
# 75%    17647.000000
# max    48611.000000

# %%
data.isnull().sum()
# Out:
# Area            0
# BHK             0
# Bathroom        0
# Furnishing      0
# Locality        0
# Parking        28
# Price           0
# Status          0
# Transaction     0
# Type            3
# Per_Sqft        0
# dtype: int64

# %%
data.sort_values(by=['Parking'], na_position="first")
# Out:
#        Area  BHK  Bathroom      Furnishing                         Locality  \
# 30   1500.0    1       2.0     Unfurnished                   Lajpat Nagar 2
# 90    900.0    1       1.0  Semi-Furnished                   Lajpat Nagar 3
# 120  1500.0    1       2.0     Unfurnished                   Lajpat Nagar 2
# 269  2799.0    4       4.0  Semi-Furnished  Kailash Colony, Greater Kailash
# 299   700.0    2       2.0     Unfurnished                            other
# ..      ...  ...       ...             ...                              ...
# 877   350.0    1       1.0     Unfurnished                            other
# 876   390.0    1       1.0     Unfurnished            DDA Lig Flats, Narela
# 970  1100.0    2       2.0  Semi-Furnished               Vasundhara Enclave
# 971   950.0    2       2.0     Unfurnished               Vasundhara Enclave
# 969   900.0    2       2.0     Unfurnished                            other
#
# ...

# %%
data['Per_Sqft'].describe()
# Out:
# count     1083.000000
# mean     13332.455217
# std       7464.567486
# min        204.000000
# 25%       7456.000000
# 50%      12222.000000
# 75%      17647.000000
# max      48611.000000
# Name: Per_Sqft, dtype: float64

# %%
def remove_outliers_sqft(obj):
    output = pd.DataFrame()
    for key,sub in obj.groupby('Locality'):
        m = np.mean(sub.Per_Sqft)
        s = np.std(sub.Per_Sqft)
        gen_df = sub[(sub.Per_Sqft > (m-s)) & (sub.Per_Sqft <= (m+s))]
        output = pd.concat([output,gen_df],ignore_index=True)
        return output

# %%
data['Per_Sqft'].describe()
# Out:
# count     1083.000000
# mean     13332.455217
# std       7464.567486
# min        204.000000
# 25%       7456.000000
# 50%      12222.000000
# 75%      17647.000000
# max      48611.000000
# Name: Per_Sqft, dtype: float64

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# 5      1300.0    4       3.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1253   1200.0    3       3.0  Semi-Furnished
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                     Locality  Parking     Price  \
# 1     J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                                      other      1.0  15500000
# 3                           Rohini Sector 24      1.0   4200000
# 4                                      other      1.0   6200000
# 5                           Rohini Sector 24      1.0  15500000
# ...

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# 5      1300.0    4       3.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1253   1200.0    3       3.0  Semi-Furnished
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                     Locality  Parking     Price  \
# 1     J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                                      other      1.0  15500000
# 3                           Rohini Sector 24      1.0   4200000
# 4                                      other      1.0   6200000
# 5                           Rohini Sector 24      1.0  15500000
# ...

# %%
data.isnull().sum()
# Out:
# Area            0
# BHK             0
# Bathroom        0
# Furnishing      0
# Locality        0
# Parking        28
# Price           0
# Status          0
# Transaction     0
# Type            3
# Per_Sqft        0
# dtype: int64

# %%
data.sort_values(by=['Type'],na_position="first")
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 511    1350.0    3       3.0  Semi-Furnished
# 512    2250.0    3       2.0  Semi-Furnished
# 719    1500.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 714    1300.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 821    1250.0    3       3.0     Unfurnished
# 242    6000.0    5       5.0  Semi-Furnished
# 823    1170.0    3       3.0     Unfurnished
# 817     450.0    1       1.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                     Locality  Parking      Price  \
# 511                                    other      NaN   25000000
# 512                                    other      NaN   10000000
# 719                                    other      1.0   13500000
# 1     J R Designers Floors, Rohini Sector 24      1.0    5000000
# 714                                    other      1.0   15000000
# ...

# %%
data.drop(data[data['Type'].isnull()].index, inplace = True)
# Out:
# C:\Users\princ\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data.sort_values(by=['Type'],na_position="first")
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 1       750.0    2       2.0  Semi-Furnished
# 714    1300.0    2       2.0  Semi-Furnished
# 715    1200.0    2       2.0     Unfurnished
# 716    1300.0    3       2.0     Unfurnished
# 717    1400.0    3       3.0       Furnished
# ...       ...  ...       ...             ...
# 821    1250.0    3       3.0     Unfurnished
# 242    6000.0    5       5.0  Semi-Furnished
# 823    1170.0    3       3.0     Unfurnished
# 817     450.0    1       1.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                     Locality  Parking      Price  \
# 1     J R Designers Floors, Rohini Sector 24      1.0    5000000
# 714                                    other      1.0   15000000
# 715             Nilgiri Apartment, Alaknanda      1.0   14300000
# 716             Nilgiri Apartment, Alaknanda      1.0   18500000
# 717                                    other      1.0   19000000
# ...

# %%
data.isnull().sum()
# Out:
# Area            0
# BHK             0
# Bathroom        0
# Furnishing      0
# Locality        0
# Parking        26
# Price           0
# Status          0
# Transaction     0
# Type            0
# Per_Sqft        0
# dtype: int64

# %%
data.sort_values(by=['Parking'],na_position="first")
# Out:
#        Area  BHK  Bathroom      Furnishing                         Locality  \
# 30   1500.0    1       2.0     Unfurnished                   Lajpat Nagar 2
# 90    900.0    1       1.0  Semi-Furnished                   Lajpat Nagar 3
# 120  1500.0    1       2.0     Unfurnished                   Lajpat Nagar 2
# 269  2799.0    4       4.0  Semi-Furnished  Kailash Colony, Greater Kailash
# 299   700.0    2       2.0     Unfurnished                            other
# ..      ...  ...       ...             ...                              ...
# 880   500.0    1       1.0     Unfurnished                            other
# 877   350.0    1       1.0     Unfurnished                            other
# 969   900.0    2       2.0     Unfurnished                            other
# 970  1100.0    2       2.0  Semi-Furnished               Vasundhara Enclave
# 971   950.0    2       2.0     Unfurnished               Vasundhara Enclave
#
# ...

# %%
data['Parking'].describe()
# Out:
# count    1054.000000
# mean        1.989564
# std         6.567560
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max       114.000000
# Name: Parking, dtype: float64

# %%
data['Parking'].fillna(1.0,inplace=True)
# Out:
# C:\Users\princ\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data['Parking'].describe()
# Out:
# count    1080.000000
# mean        1.965741
# std         6.489725
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max       114.000000
# Name: Parking, dtype: float64

# %%
data.sort_values(by=['Parking'],ascending=[False])
# Out:
#          Area  BHK  Bathroom      Furnishing               Locality  Parking  \
# 971     950.0    2       2.0     Unfurnished     Vasundhara Enclave    114.0
# 970    1100.0    2       2.0  Semi-Furnished     Vasundhara Enclave    114.0
# 969     900.0    2       2.0     Unfurnished                  other    114.0
# 875     365.0    1       1.0     Unfurnished                 Narela     39.0
# 881     350.0    1       1.0     Unfurnished  DDA Lig Flats, Narela     39.0
# ...       ...  ...       ...             ...                    ...      ...
# 517    1800.0    4       2.0       Furnished                  other      1.0
# 518    1800.0    4       3.0       Furnished                  other      1.0
# 519    1530.0    5       2.0       Furnished                  other      1.0
# 520    1750.0    4       4.0     Unfurnished                  other      1.0
# 1258  11050.0    3       3.0     Unfurnished      Chittaranjan Park      1.0
#
# ...

# %%
p_count = data['Parking'].value_counts()

# %%
p_count
# Out:
# 1.0      677
# 2.0      319
# 3.0       51
# 4.0       16
# 5.0        7
# 39.0       5
# 114.0      3
# 9.0        1
# 10.0       1
# Name: Parking, dtype: int64

# %%
p_count_5 = p_count[p_count <= 5]

# %%
data['Parking'].describe()
# Out:
# count    1080.000000
# mean        1.965741
# std         6.489725
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max       114.000000
# Name: Parking, dtype: float64

# %%
data['Parking'] = data['Parking'].apply(lambda x: 5.0 if x in p_count_5 else x)
# Out:
# C:\Users\princ\AppData\Local\Temp/ipykernel_29208/1528627654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Parking'] = data['Parking'].apply(lambda x: 5.0 if x in p_count_5 else x)

# %%
data.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# dtype: int64

# %%
data.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1080.000000  1080.000000  1080.000000  1080.000000  1.080000e+03
# mean    1617.383262     2.833333     2.666667     1.497222  2.381959e+07
# std     1640.732735     0.942263     1.041315     0.789171  2.672227e+07
# min      300.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      945.000000     2.000000     2.000000     1.000000  7.172500e+06
# 50%     1350.000000     3.000000     2.000000     1.000000  1.590000e+07
# 75%     1800.000000     3.000000     3.000000     2.000000  2.850000e+07
# max    24300.000000     7.000000     7.000000     5.000000  2.400000e+08
#
#            Per_Sqft
# count   1080.000000
# mean   13339.894444
# std     7467.200686
# min      204.000000
# 25%     7459.500000
# 50%    12222.000000
# 75%    17647.000000
# max    48611.000000

# %%
def bhk_outlier(df):
    exclude_index = np.array([])
    for location,location_def in df.groupby('Locality'):
        bhk_stats = {}
        for bhk , bhk_def in location_def.groupby('BHK'):
            bhk_stats[bhk] = {
                'mean' : np.mean(bhk_def.Per_Sqft),
                'std' : np.std(bhk_def.Per_Sqft),
                'count' : bhk_def.shape[0]
            }
        for bhk,bhk_def in location_def.groupby('BHK'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>3:
                exclude_index = np.append(exclude_index,bhk_def[bhk_def.Per_Sqft<(stats['mean'])].index.values)
    return df.drop(exclude_index,axis="index")

# %%
data.shape
# Out:
# (1080, 11)

# %%
data = bhk_outlier(data)

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# 5      1300.0    4       3.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1252   1800.0    3       3.0  Semi-Furnished
# 1253   1200.0    3       3.0  Semi-Furnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                     Locality  Parking     Price  \
# 1     J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                                      other      1.0  15500000
# 3                           Rohini Sector 24      1.0   4200000
# 4                                      other      1.0   6200000
# 5                           Rohini Sector 24      1.0  15500000
# ...

# %%
data.drop(columns=['Per_Sqft'],inplace=True)

# %%
data.groupby('Furnishing').count()
data['Furnishing'].unique()
# Out:
# array(['Semi-Furnished', 'Furnished', 'Unfurnished'], dtype=object)

# %%
x = data.drop(columns=['Price','Furnishing','Status','Transaction','Type','Parking'])
y = data['Price']

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# 5      1300.0    4       3.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1252   1800.0    3       3.0  Semi-Furnished
# 1253   1200.0    3       3.0  Semi-Furnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                     Locality  Parking     Price  \
# 1     J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                                      other      1.0  15500000
# 3                           Rohini Sector 24      1.0   4200000
# 4                                      other      1.0   6200000
# 5                           Rohini Sector 24      1.0  15500000
# ...

# %%
x
# Out:
#          Area  BHK  Bathroom                                Locality
# 1       750.0    2       2.0  J R Designers Floors, Rohini Sector 24
# 2       950.0    2       2.0                                   other
# 3       600.0    2       2.0                        Rohini Sector 24
# 4       650.0    2       2.0                                   other
# 5      1300.0    4       3.0                        Rohini Sector 24
# ...       ...  ...       ...                                     ...
# 1252   1800.0    3       3.0                                   other
# 1253   1200.0    3       3.0                       Chittaranjan Park
# 1255   1050.0    3       2.0                       Chittaranjan Park
# 1257    990.0    2       2.0                                   other
# 1258  11050.0    3       3.0                       Chittaranjan Park
#
# [866 rows x 4 columns]

# %%
y
# Out:
# 1        5000000
# 2       15500000
# 3        4200000
# 4        6200000
# 5       15500000
#           ...
# 1252    26000000
# 1253    16500000
# 1255    12500000
# 1257    11500000
# 1258    18500000
# Name: Price, Length: 866, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
x_train ,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
import pickle
# Out:
# (692, 4)
# (174, 4)

# %%
column_trans = make_column_transformer((OneHotEncoder(sparse=False),['Locality']),remainder="passthrough")

# %%
scaler = StandardScaler()

# %%
lr = LinearRegression(normalize=True)

# %%
pipe = make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['Locality'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression(normalize=True))])

# %%
y_pred_lr = pipe.predict(x_test)

# %%
r2_score(y_test,y_pred_lr)
pickle.dump(pipe,open('LinearModel.pkl','wb'))

# %%
# Lasso Function
lasso = Lasso()

# %%
pipe = make_pipeline(column_trans,scaler,lasso)

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\Users\princ\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7779263301556080.0, tolerance: 52682876871719.66
#   model = cd_fast.enet_coordinate_descent(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['Locality'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso = pipe.predict(x_test)
r2_score(y_test,y_pred_lasso)
# Out:
# 33385291.72660611

# %%
ridge = Ridge()

# %%
pipe = make_pipeline(column_trans,scaler,ridge)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['Locality'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge = pipe.predict(x_test)
r2_score(y_test,y_pred_ridge)
# Out:
# 0.7390864910368551

# %%
import pickle

# %%
pickle.dump(pipe,open('RidgeModel.pkl','wb'))
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# 5      1300.0    4       3.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1252   1800.0    3       3.0  Semi-Furnished
# 1253   1200.0    3       3.0  Semi-Furnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                     Locality  Parking     Price  \
# 1     J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                                      other      1.0  15500000
# 3                           Rohini Sector 24      1.0   4200000
# 4                                      other      1.0   6200000
# 5                           Rohini Sector 24      1.0  15500000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 866 entries, 1 to 1258
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         866 non-null    float64
#  1   BHK          866 non-null    int64
#  2   Bathroom     866 non-null    float64
#  3   Furnishing   866 non-null    object
#  4   Locality     866 non-null    object
#  5   Parking      866 non-null    float64
#  6   Price        866 non-null    int64
#  7   Status       866 non-null    object
#  8   Transaction  866 non-null    object
#  9   Type         866 non-null    object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 74.4+ KB

# %%
#data.to_csv("Cleaned_data.csv")

# %%
def predict1(a,b,bath,l):
     input = pd.DataFrame([[a,b,bath,l]], columns=['Area', 'BHK', 'Bathroom', 'Locality'])
     prediction = pipe.predict(input)
     return prediction

# %%
a= predict1(1800.0,4,3.0,"other")
a = a.astype(int)
print("Price : ",int(a),"Rs.")
# Out:
# Price :  33311969 Rs.
